# %%
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
SAVE_MODEL = True

import sys
file_path = os.path.abspath('../utils')
print(file_path)
sys.path.append(file_path)
from CommonUtil import *

import glob # List 불러오는 라이브러리
import numpy as np # 배열처리하는 라이브러리
# import pandas as pd #데이터 분석 라이브러리  (대용량 데이터 처리)
# from PIL import Image # Python Image Library 이미지 라이브러리
import cv2

import tensorflow as tf
tf.compat.v1.enable_eager_execution()
import matplotlib.pyplot as plt# 이미지, 그래프 보는 라이브러리

from tqdm import tqdm, tqdm_notebook
import pandas as pd
import SimpleITK as sitk

from absl import logging
logging._warn_preinit_stderr = 0
logging.warning('Worrying Stuff')
# Out:
# /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/utils
# 2024-07-01 16:54:22.355472: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-01 16:54:23.043428: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/gil/anaconda3/envs/msb_2.11.0/lib/python3.10/site-packages/cv2/../../lib64:/usr/local/cuda-11.3/lib64:
# 2024-07-01 16:54:23.043963: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/gil/anaconda3/envs/msb_2.11.0/lib/python3.10/site-packages/cv2/../../lib64:/usr/local/cuda-11.3/lib64:
# 2024-07-01 16:54:23.043970: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:absl:Worrying Stuff

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17354337897622353718
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 82739068928
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#   }
# }
# incarnation: 17288560304413313488
# physical_device_desc: "device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:c1:00.0, compute capability: 8.0"
# xla_global_id: 416903419
# ]
# 2024-07-01 16:54:23.960998: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-01 16:54:24.753100: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /device:GPU:0 with 78906 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:c1:00.0, compute capability: 8.0

# %%
# 전처리한 데이터 폴더 위치
base_dir = os.path.abspath(f'./data/data_preprocessing')

# 학습한 인공지능 모델 위치
saveDir= os.path.abspath(f'./result')
createFolder(saveDir)

print(base_dir)
print(saveDir)
# Out:
# /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/data/data_preprocessing
# /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result

# %% [markdown]
# # 전처리한 데이터 불러오기

# %%
# 이미지 데이터 리스트 불러오기
image_list = sorted(glob.glob(f'{base_dir}/img*.png'))
print(len(image_list), image_list[0])
# Out:
# 150 /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/data/data_preprocessing/img_0.png

# %%
# 데이터 로드하는 함수 정의하기
def data_load(image_list, test:bool=False):
    image_data = []
    label_data = []
    
    for i in tqdm_notebook(range(len(image_list)), leave=False):
        image_path = image_list[i]
        label_path = image_path.replace('/img', '/lab')

        image = cv2.imread(image_path, 0)
        label = cv2.imread(label_path, 0) > 127.5
        
        image = image.astype(np.float32)
        label = label.astype(np.float32)
        
        image = image / 255.0
        label_max = np.max(label)
        if label_max > 1.0 :
            label = label / 255.0
                    
        image_data.append(image)
        label_data.append(label)
        
    image_data = np.array(image_data)
    label_data = np.array(label_data)
    
    image_data = np.expand_dims(image_data, -1)
    label_data = np.expand_dims(label_data, -1)

    print(image_data.shape, np.min(image_data), np.max(image_data))
    print(label_data.shape, np.min(label_data), np.max(label_data))
    
    return image_data, label_data

# 데이터 로드하기 
image_data, label_data = data_load(image_list)
# Out:
# /tmp/ipykernel_540437/4090016382.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(len(image_list)), leave=False):
#   0%|          | 0/150 [00:00<?, ?it/s]
# (150, 128, 128, 1) 0.0 1.0
# (150, 128, 128, 1) 0.0 1.0

# %%
# 학습용 데이터, 검증용 데이터, 데스트 데이터 분리하기 
train_ratio = int(0.8 * len(image_data))
validation_ratio = int(0.9 * len(image_data))

train_image = image_data[:train_ratio]
train_label = label_data[:train_ratio]
validation_image = image_data[train_ratio:validation_ratio]
validation_label = label_data[train_ratio:validation_ratio]
test_image = image_data[validation_ratio:]
test_label = label_data[validation_ratio:]


train_image, train_label = shuffle(train_image, train_label)
validation_image, validation_label = shuffle(validation_image, validation_label)
test_image, test_label = shuffle(test_image, test_label)

print('training dataset')
print(train_image.shape, np.min(train_image), np.max(train_image))
print(train_label.shape, np.min(train_label), np.max(train_label))
print('validatio dataset')
print(validation_image.shape, np.min(validation_image), np.max(validation_image))
print(validation_label.shape, np.min(validation_label), np.max(validation_label))
print('test dataset')
print(test_image.shape, np.min(test_image), np.max(test_image))
print(test_label.shape, np.min(test_label), np.max(test_label))
# Out:
# training dataset
# (120, 128, 128, 1) 0.0 1.0
# (120, 128, 128, 1) 0.0 1.0
# validatio dataset
# (15, 128, 128, 1) 0.0 0.99215686
# (15, 128, 128, 1) 0.0 1.0
# test dataset
# (15, 128, 128, 1) 0.0 1.0
# (15, 128, 128, 1) 0.0 1.0

# %% [markdown]
# # Model 정의하기

# %%
# 인공지능 모델 저장할 위치
model_name = f'model'
model_path = f'{saveDir}/{model_name}.h5'
best_model_path = f'{saveDir}/{model_name}_best.h5'

print(model_path)
print(best_model_path)
# Out:
# /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model.h5
# /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5

# %%
# 인공지능 모델 (U-Net) 정의하기

import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, History, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.layers import Input, Dropout, concatenate, Conv2D, MaxPooling2D, UpSampling2D, Activation, Conv2DTranspose, BatchNormalization, add, multiply
import tensorflow.keras.backend as K

def Conv2D_block(input_layer, out_n_filters, kernel_size=[3,3], stride=[1,1], padding='same'):
    
    layer = input_layer
    
    for i in range(2):
        
        layer = Conv2D(out_n_filters, kernel_size, strides=stride, padding=padding)(layer)
        layer = BatchNormalization()(layer) 
        layer = Activation('relu')(layer) # ReLU
        
    out_layer = layer
    
    return out_layer

def Up_and_Concate(down_layer, layer):
    
    input_channel = down_layer.get_shape().as_list()[3]
    output_channel = input_channel // 2
    
    up = UpSampling2D(size = (2,2))(down_layer)

    concate = concatenate([up, layer])
    return concate


def classifier(conv_last, n_label, activation):
    x = Conv2D(n_label, kernel_size=[1, 1], padding='same')(conv_last) # 필터셋개수=레이블개수, # 필터셋사이즈=[1,1], 패딩
    output = Activation(activation)(x)  
   
    return output

def build_model(input_shape, classes, activation='sigmoid'): # image Segmentation을 위한 Convolutional Network End-to-End 방식
        
    inputs = Input(input_shape, dtype = 'float32')
    x = inputs
    depth = 4 # 채널 개수
    features = 32 # 특징 개수
    down_layer = []
    
    
    for i in range(depth):
        
        x = Conv2D_block(x, features) 
        down_layer.append(x)
        x = MaxPooling2D(pool_size=[2, 2], strides=[2, 2])(x)

        features = features * 2
        
    x = Conv2D_block(x, features)
    
    for i in reversed(range(depth)):

        features = features // 2
        
        x = Up_and_Concate(x, down_layer[i])
        x = Conv2D_block(x, features)
    
    
    output = classifier(x, classes, activation)
    model = Model(inputs = inputs, outputs = output)
    
    return model

# %%
# 모델 빌드하기
inp_shape = train_image[0].shape
print(train_image[0].shape)

model = build_model(inp_shape, 1)
model.summary()
# Out:
# (128, 128, 1)
# 2024-07-01 16:54:25.497084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78906 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:c1:00.0, compute capability: 8.0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  320         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  147584      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 16, 16, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 256)  590080      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 16, 16, 256)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)   0           ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 512)    1180160     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 512)   2048        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 8, 8, 512)    0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 512)    2359808     ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 512)   2048        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 8, 8, 512)    0           ['batch_normalization_9[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 512)  0           ['activation_9[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 768)  0           ['up_sampling2d[0][0]',
#                                                                   'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 256)  1769728     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 256)  0          ['activation_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 384)  0           ['up_sampling2d_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 128)  442496      ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_13[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 128)  0          ['activation_13[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 192)  0           ['up_sampling2d_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   110656      ['concatenate_2[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_15[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 64  0          ['activation_15[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 96  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 32  27680       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 32  128        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 32  9248        ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 32  128        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  33          ['activation_17[0][0]']
#
#  activation_18 (Activation)     (None, 128, 128, 1)  0           ['conv2d_18[0][0]']
#
# ==================================================================================================
# Total params: 7,857,857
# Trainable params: 7,851,969
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
# 모델 학습에 사용되는 metrix 와 loss function
def dice_coef(y_true, y_pred, smooth=0.001):
    y_true_f = K.flatten(y_true)# y_true를 일렬로 정렬한다.
    y_pred_f = K.flatten(y_pred) # y_pred를 일렬로 정렬한다.
    intersection = K.sum(y_true_f * y_pred_f)# y_true_f와 y_pred_f, 두 이미지를 곱해서 교집합을 구한다.
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# 모델 컴파일 하기
model.compile(optimizer=Adam(lr=0.001), loss=dice_coef_loss, metrics=[dice_coef, 'acc'])

# 모델 학습에 사용되는 콜백함수 정의하기
checkpointer = ModelCheckpoint(best_model_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1)
earlystopper = EarlyStopping(monitor='val_loss', patience=20, verbose=1)
if SAVE_MODEL:
    callbacks_list = [checkpointer, reduce_lr, earlystopper]
else:
    callbacks_list = [reduce_lr, earlystopper]

print(train_image.shape, np.min(train_image), np.max(train_image))
print(train_label.shape, np.min(train_label), np.max(train_label))
print(validation_image.shape, np.min(validation_image), np.max(validation_image))
print(validation_label.shape, np.min(validation_label), np.max(validation_label))
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# (120, 128, 128, 1) 0.0 1.0
# (120, 128, 128, 1) 0.0 1.0
# (15, 128, 128, 1) 0.0 0.99215686
# (15, 128, 128, 1) 0.0 1.0

# %%
from datetime import datetime
startTime = datetime.now()

batch_size = 4
epochs = 400

print('Start Time : {0}'.format(startTime))
hist = model.fit(train_image, train_label, batch_size=batch_size, epochs=epochs, verbose=1,
              validation_data= (validation_image, validation_label), 
              shuffle=True, callbacks=callbacks_list)

endTime = datetime.now()
runTime = endTime - startTime

print('End Time : {0}'.format(endTime))
print('Running Time : ' + str(runTime))

print('Done training')
# Out:
# Start Time : 2024-07-01 16:54:26.671088
# Epoch 1/400
# 2024-07-01 16:54:30.771523: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8201
# 2024-07-01 16:54:32.829531: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f5f6b4a9a90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-01 16:54:32.829586: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA A100 80GB PCIe, Compute Capability 8.0
# 2024-07-01 16:54:32.834054: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-01 16:54:32.959238: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 28/30 [===========================>..] - ETA: 0s - loss: 0.6747 - dice_coef: 0.3253 - acc: 0.8929
# Epoch 1: val_loss improved from inf to 0.86190, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 14s 81ms/step - loss: 0.6671 - dice_coef: 0.3329 - acc: 0.8968 - val_loss: 0.8619 - val_dice_coef: 0.1371 - val_acc: 0.5190 - lr: 0.0010
# Epoch 2/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.5266 - dice_coef: 0.4734 - acc: 0.9542
# Epoch 2: val_loss improved from 0.86190 to 0.79053, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 63ms/step - loss: 0.5241 - dice_coef: 0.4759 - acc: 0.9547 - val_loss: 0.7905 - val_dice_coef: 0.2096 - val_acc: 0.9092 - lr: 0.0010
# Epoch 3/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.4284 - dice_coef: 0.5716 - acc: 0.9658
# Epoch 3: val_loss improved from 0.79053 to 0.74954, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 64ms/step - loss: 0.4260 - dice_coef: 0.5740 - acc: 0.9659 - val_loss: 0.7495 - val_dice_coef: 0.2493 - val_acc: 0.8230 - lr: 0.0010
# Epoch 4/400
# 30/30 [==============================] - ETA: 0s - loss: 0.3422 - dice_coef: 0.6578 - acc: 0.9726
# Epoch 4: val_loss did not improve from 0.74954
# 30/30 [==============================] - 1s 22ms/step - loss: 0.3422 - dice_coef: 0.6578 - acc: 0.9726 - val_loss: 0.9451 - val_dice_coef: 0.0548 - val_acc: 0.9467 - lr: 0.0010
# Epoch 5/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.2856 - dice_coef: 0.7144 - acc: 0.9762
# Epoch 5: val_loss did not improve from 0.74954
# 30/30 [==============================] - 1s 22ms/step - loss: 0.2838 - dice_coef: 0.7162 - acc: 0.9763 - val_loss: 0.9638 - val_dice_coef: 0.0361 - val_acc: 0.9467 - lr: 0.0010
# Epoch 6/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.2398 - dice_coef: 0.7602 - acc: 0.9798
# Epoch 6: val_loss did not improve from 0.74954
# 30/30 [==============================] - 1s 22ms/step - loss: 0.2381 - dice_coef: 0.7619 - acc: 0.9800 - val_loss: 0.9680 - val_dice_coef: 0.0319 - val_acc: 0.9467 - lr: 0.0010
# Epoch 7/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1976 - dice_coef: 0.8024 - acc: 0.9838
# Epoch 7: val_loss did not improve from 0.74954
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1974 - dice_coef: 0.8026 - acc: 0.9837 - val_loss: 0.9762 - val_dice_coef: 0.0238 - val_acc: 0.9466 - lr: 0.0010
# Epoch 8/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.1738 - dice_coef: 0.8262 - acc: 0.9851
# Epoch 8: val_loss did not improve from 0.74954
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 30/30 [==============================] - 1s 22ms/step - loss: 0.
saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 60ms/step - loss: 0.1200 - dice_coef: 0.8800 - acc: 0.9903 - val_loss: 0.1615 - val_dice_coef: 0.8397 - val_acc: 0.9855 - lr: 1.0000e-05
# Epoch 26/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1189 - dice_coef: 0.8811 - acc: 0.9903
# Epoch 26: val_loss improved from 0.16149 to 0.16081, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 66ms/step - loss: 0.1188 - dice_coef: 0.8812 - acc: 0.9904 - val_loss: 0.1608 - val_dice_coef: 0.8404 - val_acc: 0.9855 - lr: 1.0000e-05
# Epoch 27/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1194 - dice_coef: 0.8806 - acc: 0.9903
# Epoch 27: val_loss improved from 0.16081 to 0.15979, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 65ms/step - loss: 0.1192 - dice_coef: 0.8808 - acc: 0.9903 - val_loss: 0.1598 - val_dice_coef: 0.8414 - val_acc: 0.9857 - lr: 1.0000e-05
# Epoch 28/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1180 - dice_coef: 0.8820 - acc: 0.9905
# Epoch 28: val_loss improved from 0.15979 to 0.15957, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 63ms/step - loss: 0.1187 - dice_coef: 0.8813 - acc: 0.9904 - val_loss: 0.1596 - val_dice_coef: 0.8416 - val_acc: 0.9856 - lr: 1.0000e-05
# Epoch 29/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1177 - dice_coef: 0.8823 - acc: 0.9905
# Epoch 29: val_loss improved from 0.15957 to 0.15910, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 70ms/step - loss: 0.1180 - dice_coef: 0.8820 - acc: 0.9905 - val_loss: 0.1591 - val_dice_coef: 0.8421 - val_acc: 0.9857 - lr: 1.0000e-05
# Epoch 30/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1177 - dice_coef: 0.8823 - acc: 0.9905
# Epoch 30: val_loss improved from 0.15910 to 0.15880, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 61ms/step - loss: 0.1179 - dice_coef: 0.8821 - acc: 0.9905 - val_loss: 0.1588 - val_dice_coef: 0.8424 - val_acc: 0.9857 - lr: 1.0000e-05
# Epoch 31/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1169 - dice_coef: 0.8831 - acc: 0.9906
# Epoch 31: val_loss improved from 0.15880 to 0.15862, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 61ms/step - loss: 0.1172 - dice_coef: 0.8828 - acc: 0.9905 - val_loss: 0.1586 - val_dice_coef: 0.8425 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 32/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1170 - dice_coef: 0.8830 - acc: 0.9906
# Epoch 32: val_loss improved from 0.15862 to 0.15850, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 67ms/step - loss: 0.1169 - dice_coef: 0.8831 - acc: 0.9906 - val_loss: 0.1585 - val_dice_coef: 0.8427 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 33/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1168 - dice_coef: 0.8832 - acc: 0.9906
# Epoch 33: val_loss improved from 0.15850 to 0.15822, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1056 - dice_coef: 0.8944 - acc: 0.9915 - val_loss: 0.1546 - val_dice_coef: 0.8467 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 60/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1053 - dice_coef: 0.8947 - acc: 0.9916
# Epoch 60: val_loss improved from 0.15454 to 0.15448, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 64ms/step - loss: 0.1049 - dice_coef: 0.8951 - acc: 0.9916 - val_loss: 0.1545 - val_dice_coef: 0.8468 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 61/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.1043 - dice_coef: 0.8957 - acc: 0.9917
# Epoch 61: val_loss improved from 0.15448 to 0.15439, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 60ms/step - loss: 0.1049 - dice_coef: 0.8951 - acc: 0.9916 - val_loss: 0.1544 - val_dice_coef: 0.8468 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 62/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.1042 - dice_coef: 0.8958 - acc: 0.9917
# Epoch 62: val_loss improved from 0.15439 to 0.15410, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 60ms/step - loss: 0.1042 - dice_coef: 0.8958 - acc: 0.9916 - val_loss: 0.1541 - val_dice_coef: 0.8471 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 63/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1039 - dice_coef: 0.8961 - acc: 0.9917
# Epoch 63: val_loss did not improve from 0.15410
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1039 - dice_coef: 0.8961 - acc: 0.9917 - val_loss: 0.1542 - val_dice_coef: 0.8470 - val_acc: 0.9857 - lr: 1.0000e-05
# Epoch 64/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.1036 - dice_coef: 0.8964 - acc: 0.9917
# Epoch 64: val_loss did not improve from 0.15410
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1037 - dice_coef: 0.8963 - acc: 0.9917 - val_loss: 0.1541 - val_dice_coef: 0.8471 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 65/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1023 - dice_coef: 0.8977 - acc: 0.9918
# Epoch 65: val_loss did not improve from 0.15410
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1029 - dice_coef: 0.8971 - acc: 0.9918 - val_loss: 0.1543 - val_dice_coef: 0.8470 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 66/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.1019 - dice_coef: 0.8981 - acc: 0.9919
# Epoch 66: val_loss improved from 0.15410 to 0.15398, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 63ms/step - loss: 0.1022 - dice_coef: 0.8978 - acc: 0.9918 - val_loss: 0.1540 - val_dice_coef: 0.8473 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 67/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.1020 - dice_coef: 0.8980 - acc: 0.9918
# Epoch 67: val_loss improved from 0.15398 to 0.15386, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 60ms/step - loss: 0.1018 - dice_coef: 0.8982 - acc: 0.9919 - val_loss: 0.1539 - val_dice_coef: 0.8474 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 68/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1009 - dice_coef: 0.8991 - acc: 0.9919
# Epoch 68: val_loss improved from 0.15386 to 0.15373, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 67ms/step - loss: 0.1014 - dice_coef: 0.8986 - acc: 0.9919 - val_loss: 0.1537 - val_dice_coef: 0.8475 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 69/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.1015 - dice_coef: 0.8985 - acc: 0.9919
# Epoch 69: val_loss improved from 0.15373 to 0.15359, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 66ms/step - loss: 0.1013 - dice_coef: 0.8987 - acc: 0.9919 - val_loss: 0.1536 - val_dice_coef: 0.8476 - val_acc: 0.9857 - lr: 1.0000e-05
# Epoch 70/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.1006 - dice_coef: 0.8994 - acc: 0.9920
# Epoch 70: val_loss improved from 0.15359 to 0.15326, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 59ms/step - loss: 0.1006 - dice_coef: 0.8994 - acc: 0.9920 - val_loss: 0.1533 - val_dice_coef: 0.8480 - val_acc: 0.9857 - lr: 1.0000e-05
# Epoch 71/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.1002 - dice_coef: 0.8998 - acc: 0.9920
# Epoch 71: val_loss improved from 0.15326 to 0.15319, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 65ms/step - loss: 0.1004 - dice_coef: 0.8996 - acc: 0.9920 - val_loss: 0.1532 - val_dice_coef: 0.8480 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 72/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.1000 - dice_coef: 0.9000 - acc: 0.9921
# Epoch 72: val_loss improved from 0.15319 to 0.15311, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 64ms/step - loss: 0.0998 - dice_coef: 0.9002 - acc: 0.9920 - val_loss: 0.1531 - val_dice_coef: 0.8482 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 73/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0987 - dice_coef: 0.9013 - acc: 0.9921
# Epoch 73: val_loss improved from 0.15311 to 0.15296, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 64ms/step - loss: 0.0990 - dice_coef: 0.9010 - acc: 0.9921 - val_loss: 0.1530 - val_dice_coef: 0.8483 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 74/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0982 - dice_coef: 0.9018 - acc: 0.9922
# Epoch 74: val_loss improved from 0.15296 to 0.15275, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 64ms/step - loss: 0.0989 - dice_coef: 0.9011 - acc: 0.9921 - val_loss: 0.1527 - val_dice_coef: 0.8485 - val_acc: 0.9859 - lr: 1.0000e-05
# Epoch 75/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0988 - dice_coef: 0.9012 - acc: 0.9921
# Epoch 75: val_loss did not improve from 0.15275
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0983 - dice_coef: 0.9017 - acc: 0.9922 - val_loss: 0.1530 - val_dice_coef: 0.8482 - val_acc: 0.9859 - lr: 1.0000e-05
# Epoch 76/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0980 - dice_coef: 0.9020 - acc: 0.9922
# Epoch 76: val_loss improved from 0.15275 to 0.15271, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 60ms/step - loss: 0.0981 - dice_coef: 0.9019 - acc: 0.9922 - val_loss: 0.1527 - val_dice_coef: 0.8485 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 77/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0976 - dice_coef: 0.9024 - acc: 0.9922
# Epoch 77: val_loss did not improve from 0.15271
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0977 - dice_coef: 0.9023 - acc: 0.9922 - val_loss: 0.1530 - val_dice_coef: 0.8483 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 78/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0962 - dice_coef: 0.9038 - acc: 0.9923
# Epoch 78: val_loss improved from 0.15271 to 0.15261, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 60ms/step - loss: 0.0969 - dice_coef: 0.9031 - acc: 0.9923 - val_loss: 0.1526 - val_dice_coef: 0.8486 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 79/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0968 - dice_coef: 0.9032 - acc: 0.9924
# Epoch 79: val_loss improved from 0.15261 to 0.15258, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 64ms/step - loss: 0.0970 - dice_coef: 0.9030 - acc: 0.9923 - val_loss: 0.1526 - val_dice_coef: 0.8486 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 80/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0958 - dice_coef: 0.9042 - acc: 0.9924
# Epoch 80: val_loss did not improve from 0.15258
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0962 - dice_coef: 0.9038 - acc: 0.9923 - val_loss: 0.1526 - val_dice_coef: 0.8486 - val_acc: 0.9859 - lr: 1.0000e-05
# Epoch 81/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0959 - dice_coef: 0.9041 - acc: 0.9923
# Epoch 81: val_loss did not improve from 0.15258
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0955 - dice_coef: 0.9045 - acc: 0.9924 - val_loss: 0.1526 - val_dice_coef: 0.8486 - val_acc: 0.9857 - lr: 1.0000e-05
# Epoch 82/400
# 30/30 [==============================] - ETA: 0s - loss: 0.0953 - dice_coef: 0.9047 - acc: 0.9924
# Epoch 82: val_loss improved from 0.15258 to 0.15254, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 61ms/step - loss: 0.0953 - dice_coef: 0.9047 - acc: 0.9924 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9858 - lr: 1.0000e-05
# Epoch 83/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0943 - dice_coef: 0.9057 - acc: 0.9925
# Epoch 83: val_loss did not improve from 0.15254
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0948 - dice_coef: 0.9052 - acc: 0.9925 - val_loss: 0.1526 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-05
# Epoch 84/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0944 - dice_coef: 0.9056 - acc: 0.9925
# Epoch 84: val_loss did not improve from 0.15254
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0946 - dice_coef: 0.9054 - acc: 0.9925 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-06
# Epoch 85/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0941 - dice_coef: 0.9059 - acc: 0.9925
# Epoch 85: val_loss improved from 0.15254 to 0.15250, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0940 - dice_coef: 0.9060 - acc: 0.9925 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-06
# Epoch 86/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0946 - dice_coef: 0.9054 - acc: 0.9924
# Epoch 86: val_loss improved from 0.15250 to 0.15249, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 64ms/step - loss: 0.0940 - dice_coef: 0.9060 - acc: 0.9925 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-06
# Epoch 87/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0937 - dice_coef: 0.9063 - acc: 0.9926
# Epoch 87: val_loss improved from 0.15249 to 0.15246, saving model to /home/gil/gcubme_ai2/Workspace/SB_MUN/20_강의_스마트헬스케어/project_2/result/model_best.h5
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0938 - dice_coef: 0.9062 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-06
# Epoch 88/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0933 - dice_coef: 0.9067 - acc: 0.9926
# Epoch 88: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0936 - dice_coef: 0.9064 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-06
# Epoch 89/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0939 - dice_coef: 0.9061 - acc: 0.9926
# Epoch 89: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0941 - dice_coef: 0.9059 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-06
# Epoch 90/400
# 30/30 [==============================] - ETA: 0s - loss: 0.0937 - dice_coef: 0.9063 - acc: 0.9926
# Epoch 90: val_loss did not improve from 0.15246
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0937 - dice_coef: 0.9063 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-06
# Epoch 91/400
# 27/30 [==========================>...] - ETA: 0s - loss: 0.0935 - dice_coef: 0.9065 - acc: 0.9926
# Epoch 91: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0936 - dice_coef: 0.9064 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-07
# Epoch 92/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0945 - dice_coef: 0.9055 - acc: 0.9925
# Epoch 92: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0940 - dice_coef: 0.9060 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-07
# Epoch 93/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0934 - dice_coef: 0.9066 - acc: 0.9926
# Epoch 93: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0937 - dice_coef: 0.9063 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-07
# Epoch 94/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0941 - dice_coef: 0.9059 - acc: 0.9925
# Epoch 94: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0938 - dice_coef: 0.9062 - acc: 0.9925 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-07
# Epoch 95/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0934 - dice_coef: 0.9066 - acc: 0.9926
# Epoch 95: val_loss did not improve from 0.15246
#
# Epoch 95: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0936 - dice_coef: 0.9064 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-07
# Epoch 96/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0935 - dice_coef: 0.9065 - acc: 0.9926
# Epoch 96: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0937 - dice_coef: 0.9063 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-08
# Epoch 97/400
# 30/30 [==============================] - ETA: 0s - loss: 0.0940 - dice_coef: 0.9060 - acc: 0.9926
# Epoch 97: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0940 - dice_coef: 0.9060 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-08
# Epoch 98/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0932 - dice_coef: 0.9068 - acc: 0.9926
# Epoch 98: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0937 - dice_coef: 0.9063 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-08
# Epoch 99/400
# 30/30 [==============================] - ETA: 0s - loss: 0.0938 - dice_coef: 0.9062 - acc: 0.9926
# Epoch 99: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0938 - dice_coef: 0.9062 - acc: 0.9926 - val_loss: 0.1526 - val_dice_coef: 0.8486 - val_acc: 0.9857 - lr: 1.0000e-08
# Epoch 100/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0932 - dice_coef: 0.9068 - acc: 0.9926
# Epoch 100: val_loss did not improve from 0.15246
#
# Epoch 100: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0935 - dice_coef: 0.9065 - acc: 0.9926 - val_loss: 0.1526 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-08
# Epoch 101/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0938 - dice_coef: 0.9062 - acc: 0.9926
# Epoch 101: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0939 - dice_coef: 0.9061 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-09
# Epoch 102/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0940 - dice_coef: 0.9060 - acc: 0.9926
# Epoch 102: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0938 - dice_coef: 0.9062 - acc: 0.9926 - val_loss: 0.1526 - val_dice_coef: 0.8486 - val_acc: 0.9857 - lr: 1.0000e-09
# Epoch 103/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0932 - dice_coef: 0.9068 - acc: 0.9926
# Epoch 103: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0935 - dice_coef: 0.9065 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-09
# Epoch 104/400
# 30/30 [==============================] - ETA: 0s - loss: 0.0937 - dice_coef: 0.9063 - acc: 0.9926
# Epoch 104: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0937 - dice_coef: 0.9063 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-09
# Epoch 105/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0939 - dice_coef: 0.9061 - acc: 0.9925
# Epoch 105: val_loss did not improve from 0.15246
#
# Epoch 105: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0937 - dice_coef: 0.9063 - acc: 0.9925 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-09
# Epoch 106/400
# 29/30 [============================>.] - ETA: 0s - loss: 0.0937 - dice_coef: 0.9063 - acc: 0.9926
# Epoch 106: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0938 - dice_coef: 0.9062 - acc: 0.9926 - val_loss: 0.1526 - val_dice_coef: 0.8486 - val_acc: 0.9857 - lr: 1.0000e-10
# Epoch 107/400
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0937 - dice_coef: 0.9063 - acc: 0.9925
# Epoch 107: val_loss did not improve from 0.15246
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0936 - dice_coef: 0.9064 - acc: 0.9926 - val_loss: 0.1525 - val_dice_coef: 0.8487 - val_acc: 0.9857 - lr: 1.0000e-10
# Epoch 107: early stopping
# End Time : 2024-07-01 16:57:02.376147
# Running Time : 0:02:35.705059
# Done training

# %%
if SAVE_MODEL:
    model.save(model_path)

# %% [markdown]
# # Test Model

# %%
# 검증 데이터셋에서 가장 성능이 좋았던 베스트 모델 로드하기
from tensorflow.keras.models import load_model

model = load_model(best_model_path, custom_objects={'dice_coef_loss': dice_coef_loss, 'dice_coef': dice_coef})

# %%
# 데이터 성능 검증 지표 계산하는 함수 정의하기 
def resultConf(test_label, predict_model, weight):
    recall_list = []
    specificity_list = []
    precision_list = []
    acc_list = []
    dice_list = []
    
    all_data_result = []
    ious = []
    dices = []
    
    #for i in range(n_test):
    for i in tqdm_notebook(range(test_label.shape[0])):
            
        gt = test_label[i, :,  :, 0] # ground truth binary mask
        
        if np.sum(gt) > 0:
            pr = predict_model[i, :, :, 0] > weight# binary prediction
        
            gt = gt.astype(bool)
            pr = pr.astype(bool)
        
            # Compute scores
            seg1_n = pr == 0
            seg1_t = pr == 1
        
            gt1_n = gt == 0
            gt1_t = gt == 1
            
            tp = np.sum(seg1_t&gt1_t)
            fp = np.sum(seg1_t&gt1_n)
            tn = np.sum(seg1_n&gt1_n)    
            fn = np.sum(seg1_n&gt1_t)
            
            recall = tp / (tp + fn)
            specificity = tn / (tn + fp)
            precision = tp / (tp + fp)
            acc = (tp + tn) / (tp + tn + fp + fn)
            dice = (2 * tp) / (2*tp + fp + fn)
            
            recall_list.append(recall)
            specificity_list.append(specificity)
            precision_list.append(precision)
            acc_list.append(acc)
            dice_list.append(dice)
            
                
    dice_list = np.array(dice_list)
    recall_list = np.array(recall_list)
    specificity_list = np.array(specificity_list)
    precision_list = np.array(precision_list)
    
    dice_list = dice_list[~np.isnan(dice_list)]
    recall_list = recall_list[~np.isnan(recall_list)]
    specificity_list = specificity_list[~np.isnan(specificity_list)]
    precision_list = precision_list[~np.isnan(precision_list)]
    
    print('Done save result...')
    
    return recall_list, specificity_list, precision_list, acc_list, dice_list

def returnTable(test_label, predict_model, weight):
    recall_list, specificity_list, precision_list, acc_list, dice_list = resultConf(test_label, predict_model, weight)

    row_data1 = []
    row_item1 = []
    
    row_item1.append('{0}'.format(weight))
    row_item1.append('{0:.2f}'.format(np.mean(recall_list)*100))
    row_item1.append('{0:.2f}'.format(np.mean(specificity_list)*100))
    row_item1.append('{0:.2f}'.format(np.mean(precision_list)*100))
    row_item1.append('{0:.2f}'.format(np.mean(acc_list)*100))
    row_item1.append('{0:.2f}'.format(np.mean(dice_list)*100))
    row_data1.append(row_item1)
    
    head1 = ["Weight", "Sensitivity", "Specificity", "Precision", "Accuracy", "DSC"]
    
    return row_data1, head1

# %%
# 테스트 데이터셋을 사용한 모델 예측
predicted = model.predict(test_image, batch_size=4, verbose=1)

print(test_image.shape, np.min(test_image), np.max(test_image))
print(test_label.shape, np.min(test_label), np.max(test_label))
print(predicted.shape, np.min(predicted), np.max(predicted))
# Out:
# 4/4 [==============================] - 0s 7ms/step
# (15, 128, 128, 1) 0.0 1.0
# (15, 128, 128, 1) 0.0 1.0
# (15, 128, 128, 1) 4.024541e-06 1.0

# %%
# 테스트 데이터셋의 성능 검증 결과
from tabulate import tabulate

row_data1, head1 = returnTable(test_label, predicted, 0.5)
print(tabulate(row_data1, headers=head1, tablefmt="grid"))
# Out:
# /tmp/ipykernel_540437/3733576720.py:14: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(test_label.shape[0])):
#   0%|          | 0/15 [00:00<?, ?it/s]
# Done save result...
# +----------+---------------+---------------+-------------+------------+-------+
# |   Weight |   Sensitivity |   Specificity |   Precision |   Accuracy |   DSC |
# +==========+===============+===============+=============+============+=======+
# |      0.5 |         84.67 |         99.32 |        88.1 |      98.47 | 86.26 |
# +----------+---------------+---------------+-------------+------------+-------+

# %%
# 모델 학습 히스토리 시각화
fig = plt.figure(figsize=(12, 4))
    
ax1 = fig.add_subplot(1,2,1)
ax1.plot(hist.history['dice_coef'])
ax1.plot(hist.history['val_dice_coef'])
ax1.set_title('Model dice coef')
ax1.set_ylabel('Dice')
ax1.set_xlabel('Epoch')
ax1.legend(['Train', 'Validation'], loc='upper right', bbox_to_anchor=(1, 0.25))

ax2 = fig.add_subplot(1,2,2)
ax2.plot(hist.history['loss'])
ax2.plot(hist.history['val_loss'])
ax2.set_title('Model dice coef loss')
ax2.set_ylabel('Loss')
ax2.set_xlabel('Epoch')
ax2.legend(['Train', 'Validation'], loc='upper right', bbox_to_anchor=(1, 0.25))

# %%
pd.DataFrame({
'dice_coef':hist.history['dice_coef'],
'val_dice_coef':hist.history['val_dice_coef'],
'loss':hist.history['loss'],
'val_loss':hist.history['val_loss']   
}).to_excel(f"{saveDir}/history.xlsx",)

# %%
for i in range(0, len(test_image)):
    image = test_image[i, :, :, 0]
    label = test_label[i, :, :, 0]
    predi = predicted[i, :, :, 0] > 0.5
    
    fig = plt.figure(figsize=(12, 12))
    
    ax1 = fig.add_subplot(2,5,1)
    ax1.imshow(image,cmap='gray')
    ax1.axis('off')
    ax1.set_title(f'CT-{i}')
    
    ax2 = fig.add_subplot(2,5,2)
    ax2.imshow(label,cmap='gray')
    ax2.axis('off')
    ax2.set_title('Label')
        
    ax3 = fig.add_subplot(2,5,3)
    ax3.imshow(predi,cmap='gray')
    ax3.axis('off')
    ax3.set_title('Predicted')
    
    ax4 = fig.add_subplot(2,5,4)
    ax4.imshow(image,cmap='gray')
    tmpMask = label
    maskedRegion = np.ma.masked_where(tmpMask == 0, tmpMask)
    ax4.imshow(maskedRegion,cmap='hsv' ,alpha=0.6)
    ax4.axis('off')
    ax4.set_title('Merge-Label');
    
    ax5 = fig.add_subplot(2,5,5)
    ax5.imshow(image,cmap='gray')
    tmpMask = predi
    maskedRegion = np.ma.masked_where(tmpMask == 0, tmpMask)
    ax5.imshow(maskedRegion,cmap='hsv' ,alpha=0.6)
    ax5.axis('off')
    ax5.set_title('Merge-Predicted')
